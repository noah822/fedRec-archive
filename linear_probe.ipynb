# %%
from fed.server import Server
import flwr as fl
from torch.utils.tensorboard import SummaryWriter

from experiments.fed.dataset import (
    prepare_client_loader,
    get_default_aug
)
from experiments.mmvae.mnist.dataset import (
    audioMNIST, imageMNIST,
    mmMNIST
)
from torch.utils.data import DataLoader
import torch.nn as nn

from experiments.ssl.model import get_backbone
from experiments.ssl.dataset import get_mnist_transform
from fed.client import Client
from fed.config import STATE, LossMode

from pathlib import Path
import os

from experiments.mmvae.mnist.model import (
    get_mnist_audio_encoder,
    get_mnist_image_encoder
)
from model.loss import InfoNCE
import pandas as pd

import random

# %%
# static
def sample_client_state(num_client: int):
    states = [
        STATE.BOTH,
        STATE.BOTH,
        STATE.BOTH,
        STATE.BOTH,
        STATE.IMAGE,
        STATE.IMAGE,
        STATE.IMAGE,
        STATE.AUDIO,
        STATE.AUDIO,
        STATE.AUDIO
    ]
    random.shuffle(states)
    return states

def seed_everything(seed: int):
    import numpy as np
    import torch
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
SEED = 42
NUM_CLIENTS = 10
base_csv_path = './clients/probe'

seed_everything(SEED)

# collection of client configuration
clients_state = sample_client_state(NUM_CLIENTS)
clients_state
# Out:
# [<STATE.AUDIO: 0>,
#  <STATE.BOTH: 2>,
#  <STATE.BOTH: 2>,
#  <STATE.AUDIO: 0>,
#  <STATE.IMAGE: 1>,
#  <STATE.IMAGE: 1>,
#  <STATE.AUDIO: 0>,
#  <STATE.IMAGE: 1>,
#  <STATE.BOTH: 2>,
#  <STATE.BOTH: 2>]

# %%
import pandas as pd
import random
from fed.utils.sampling import uniform_draw_subset
from typing import List, Tuple
from torch.utils.data import Dataset, DataLoader

from experiments.mmvae.mnist.dataset import imageMNIST, audioMNIST


# sample probing dataset
for i in range(10):
    file_path = f'./clients/train/{i}.csv'
    save_path = f'./clients/probe/{i}.csv'
    uniform_draw_subset(file_path, 0.2, save_path)
    
# split probe & test file into each modality
for state in ['probe', 'test']:
    for i in range(10):
        file_path = f'./clients/{state}/{i}.csv'
        df = pd.read_csv(file_path, header=None)
        audio_df = df.iloc[:,0].to_csv(f'./clients/{state}/{i}_audio.csv', index=False, header=['audio']) 
        image_df = df.iloc[:,1].to_csv(f'./clients/{state}/{i}_image.csv', index=False, header=['image']) 

# load dataloader for each modality


probe_loaders: List[List[DataLoader]] = []
test_loaders: List[List[DataLoader]] = []

dataloader_config = {
    'batch_size' : 32,
    'shuffle' : True
}

# construct probe & test audio and image loader for each client 
for state in ['probe', 'test']:
    for cid in range(NUM_CLIENTS):
        client_loader = []
        for mod in ['audio', 'image']:
            file_path = f'./clients/{state}/{cid}_{mod}.csv'
            if mod == 'audio':
                dataset = audioMNIST(
                    csv_path=file_path 
                )
            else:
                dataset = imageMNIST(
                    csv_path=file_path
                )
            dataloader = DataLoader(dataset, **dataloader_config)
            client_loader.append(dataloader)
        if state == 'probe':
            probe_loaders.append(client_loader)
        else: # state == 'test'
            test_loaders.append(client_loader)

# %%
from fed.server import LinearProbeServer
from fed.client import LinearProbeClient
from torch.utils.tensorboard import SummaryWriter

from experiments.mmvae.mnist.model import (
    get_mnist_audio_encoder,
    get_mnist_image_encoder,
    _make_mlp
)
from model.loss import InfoNCE
import torch

CKP_PATH = './ckp/backbone/272/PoE.pt'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

EVAL_MODAL = 'audio'

def load_pretrained_backbone(model, ckp_path):
    ckp = torch.load(ckp_path)
    state_dict = ckp[EVAL_MODAL]
    model.load_state_dict(state_dict)
    return model

if EVAL_MODAL == 'audio':
    dummy_state_dict = get_mnist_audio_encoder().state_dict()
else:
    dummy_state_dict = get_mnist_image_encoder().state_dict()

def setup_client(cid: str):
    cid = int(cid)
    audio_dl, image_dl = probe_loaders[cid]
    
    if EVAL_MODAL == 'audio':
        dataloader = audio_dl
        backbone = get_mnist_audio_encoder().to(DEVICE)
    else: # 'image'
        dataloader = image_dl
        backbone = get_mnist_image_encoder().to(DEVICE)
    
    # load pretrained backbone
    pretrained_backbone = load_pretrained_backbone(backbone, CKP_PATH)
    
    # test
    head = nn.Linear(64, 10)
    loss_fn = nn.CrossEntropyLoss()
    
    # linear probe client
    client = LinearProbeClient(
        cid,
        pretrained_backbone=pretrained_backbone, 
        head=head,
        loss_fn=loss_fn,
        trainloader=dataloader, 
        device=DEVICE,
    ).to(DEVICE)

    return client

# %%
import flwr as fl
from utils.scheduler import SineAnnealing
writer = SummaryWriter('/root/tf-logs/272/probe/PoE/audio')

ckp_save_path = './ckp/head/272/PoE_audio.pt'
optim_config = {
    'lr' : 1e-2,
    'weight_decay' : 1e-5
}

# baseline
strategy = LinearProbeServer(
    NUM_CLIENTS,
    embed_dim=64,
    num_class=10,
    local_epoch=5,
    optim_config=optim_config,
    tensorboard_writer=writer,
    save_ckp_interval=5,
    save_path=ckp_save_path
)

ray_init_args = {
    'include_dashboard' : True
}

fl.simulation.start_simulation(
    strategy=strategy,
    client_fn=setup_client,
    num_clients=NUM_CLIENTS,
    client_resources={'num_cpus':2, 'num_gpus':0.1, 'max_calls':1},
    config=fl.server.ServerConfig(num_rounds=60),
    ray_init_args=ray_init_args
)
# Out:
# INFO flwr 2023-07-12 21:44:41,269 | app.py:146 | Starting Flower simulation, config: ServerConfig(num_rounds=60, round_timeout=None)
# 2023-07-12 21:44:43,522	WARNING utils.py:593 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2023-07-12 21:44:43,633	INFO worker.py:1627 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# INFO flwr 2023-07-12 21:44:44,415 | app.py:180 | Flower VCE: Ray initialized with resources: {'object_store_memory': 11386830028.0, 'memory': 22773660059.0, 'node:172.17.0.8': 1.0, 'accelerator_type:G': 1.0, 'GPU': 1.0, 'CPU': 16.0}
# INFO flwr 2023-07-12 21:44:44,416 | server.py:86 | Initializing global parameters
# INFO flwr 2023-07-12 21:44:44,420 | server.py:269 | Using initial parameters provided by strategy
# INFO flwr 2023-07-12 21:44:44,421 | server.py:88 | Evaluating initial parameters
# INFO flwr 2023-07-12 21:44:44,422 | server.py:101 | FL starting
# DEBUG flwr 2023-07-12 21:44:44,423 | server.py:218 | fit_round 1: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:44:55,891 | server.py:232 | fit_round 1 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:44:57,065 | server.py:166 | evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:44:57,067 | server.py:218 | fit_round 2: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:45:09,590 | server.py:232 | fit_round 2 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:45:09,611 | server.py:166 | evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:45:09,612 | server.py:218 | fit_round 3: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:45:22,148 | server.py:232 | fit_round 3 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:45:22,170 | server.py:166 | evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:45:22,171 | server.py:218 | fit_round 4: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:45:34,272 | server.py:232 | fit_round 4 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:45:34,293 | server.py:166 | evaluate_round 4: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:45:34,295 | server.py:218 | fit_round 5: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:45:47,729 | server.py:232 | fit_round 5 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:45:47,751 | server.py:166 | evaluate_round 5: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:45:47,752 | server.py:218 | fit_round 6: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:46:00,670 | server.py:232 | fit_round 6 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:46:00,692 | server.py:166 | evaluate_round 6: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:46:00,693 | server.py:218 | fit_round 7: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:46:12,056 | server.py:232 | fit_round 7 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:46:12,072 | server.py:166 | evaluate_round 7: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:46:12,073 | server.py:218 | fit_round 8: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:46:23,873 | server.py:232 | fit_round 8 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:46:23,901 | server.py:166 | evaluate_round 8: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:46:23,902 | server.py:218 | fit_round 9: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:46:35,350 | server.py:232 | fit_round 9 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:46:35,371 | server.py:166 | evaluate_round 9: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:46:35,373 | server.py:218 | fit_round 10: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:46:47,379 | server.py:232 | fit_round 10 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:46:47,406 | server.py:166 | evaluate_round 10: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:46:47,407 | server.py:218 | fit_round 11: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:46:58,911 | server.py:232 | fit_round 11 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:46:58,933 | server.py:166 | evaluate_round 11: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:46:58,934 | server.py:218 | fit_round 12: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:47:11,104 | server.py:232 | fit_round 12 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:47:11,125 | server.py:166 | evaluate_round 12: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:47:11,126 | server.py:218 | fit_round 13: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:47:24,033 | server.py:232 | fit_round 13 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:47:24,055 | server.py:166 | evaluate_round 13: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:47:24,056 | server.py:218 | fit_round 14: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:47:36,143 | server.py:232 | fit_round 14 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:47:36,167 | server.py:166 | evaluate_round 14: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:47:36,169 | server.py:218 | fit_round 15: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:47:47,759 | server.py:232 | fit_round 15 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:47:47,780 | server.py:166 | evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:47:47,781 | server.py:218 | fit_round 16: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:47:59,951 | server.py:232 | fit_round 16 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:47:59,977 | server.py:166 | evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:47:59,978 | server.py:218 | fit_round 17: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:48:11,918 | server.py:232 | fit_round 17 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:48:11,937 | server.py:166 | evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:48:11,938 | server.py:218 | fit_round 18: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:48:22,992 | server.py:232 | fit_round 18 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:48:23,014 | server.py:166 | evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:48:23,015 | server.py:218 | fit_round 19: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:48:35,121 | server.py:232 | fit_round 19 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:48:35,147 | server.py:166 | evaluate_round 19: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:48:35,148 | server.py:218 | fit_round 20: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:48:47,068 | server.py:232 | fit_round 20 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:48:47,088 | server.py:166 | evaluate_round 20: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:48:47,089 | server.py:218 | fit_round 21: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:48:59,730 | server.py:232 | fit_round 21 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:48:59,747 | server.py:166 | evaluate_round 21: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:48:59,748 | server.py:218 | fit_round 22: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:49:12,236 | server.py:232 | fit_round 22 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:49:12,259 | server.py:166 | evaluate_round 22: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:49:12,261 | server.py:218 | fit_round 23: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:49:24,069 | server.py:232 | fit_round 23 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:49:24,087 | server.py:166 | evaluate_round 23: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:49:24,088 | server.py:218 | fit_round 24: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:49:36,728 | server.py:232 | fit_round 24 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:49:36,757 | server.py:166 | evaluate_round 24: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:49:36,758 | server.py:218 | fit_round 25: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:49:49,036 | server.py:232 | fit_round 25 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:49:49,061 | server.py:166 | evaluate_round 25: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:49:49,062 | server.py:218 | fit_round 26: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:50:01,095 | server.py:232 | fit_round 26 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:50:01,120 | server.py:166 | evaluate_round 26: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:50:01,122 | server.py:218 | fit_round 27: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:50:12,775 | server.py:232 | fit_round 27 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:50:12,796 | server.py:166 | evaluate_round 27: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:50:12,797 | server.py:218 | fit_round 28: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:50:25,480 | server.py:232 | fit_round 28 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:50:25,502 | server.py:166 | evaluate_round 28: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:50:25,503 | server.py:218 | fit_round 29: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:50:37,747 | server.py:232 | fit_round 29 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:50:37,766 | server.py:166 | evaluate_round 29: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:50:37,768 | server.py:218 | fit_round 30: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:50:50,436 | server.py:232 | fit_round 30 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:50:50,461 | server.py:166 | evaluate_round 30: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:50:50,463 | server.py:218 | fit_round 31: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:51:02,065 | server.py:232 | fit_round 31 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:51:02,086 | server.py:166 | evaluate_round 31: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:51:02,087 | server.py:218 | fit_round 32: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:51:14,023 | server.py:232 | fit_round 32 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:51:14,047 | server.py:166 | evaluate_round 32: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:51:14,051 | server.py:218 | fit_round 33: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:51:26,380 | server.py:232 | fit_round 33 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:51:26,403 | server.py:166 | evaluate_round 33: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:51:26,405 | server.py:218 | fit_round 34: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:51:38,929 | server.py:232 | fit_round 34 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:51:38,952 | server.py:166 | evaluate_round 34: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:51:38,953 | server.py:218 | fit_round 35: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:51:51,047 | server.py:232 | fit_round 35 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:51:51,071 | server.py:166 | evaluate_round 35: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:51:51,073 | server.py:218 | fit_round 36: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:52:04,445 | server.py:232 | fit_round 36 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:52:04,467 | server.py:166 | evaluate_round 36: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:52:04,468 | server.py:218 | fit_round 37: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:52:16,136 | server.py:232 | fit_round 37 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:52:16,156 | server.py:166 | evaluate_round 37: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:52:16,157 | server.py:218 | fit_round 38: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:52:28,714 | server.py:232 | fit_round 38 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:52:28,739 | server.py:166 | evaluate_round 38: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:52:28,740 | server.py:218 | fit_round 39: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:52:41,575 | server.py:232 | fit_round 39 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:52:41,597 | server.py:166 | evaluate_round 39: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:52:41,598 | server.py:218 | fit_round 40: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:52:54,083 | server.py:232 | fit_round 40 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:52:54,105 | server.py:166 | evaluate_round 40: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:52:54,106 | server.py:218 | fit_round 41: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:53:06,596 | server.py:232 | fit_round 41 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:53:06,618 | server.py:166 | evaluate_round 41: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:53:06,620 | server.py:218 | fit_round 42: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:53:17,937 | server.py:232 | fit_round 42 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:53:17,960 | server.py:166 | evaluate_round 42: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:53:17,961 | server.py:218 | fit_round 43: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:53:29,244 | server.py:232 | fit_round 43 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:53:29,264 | server.py:166 | evaluate_round 43: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:53:29,265 | server.py:218 | fit_round 44: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:53:40,519 | server.py:232 | fit_round 44 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:53:40,543 | server.py:166 | evaluate_round 44: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:53:40,544 | server.py:218 | fit_round 45: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:53:52,632 | server.py:232 | fit_round 45 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:53:52,654 | server.py:166 | evaluate_round 45: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:53:52,656 | server.py:218 | fit_round 46: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:54:04,502 | server.py:232 | fit_round 46 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:54:04,533 | server.py:166 | evaluate_round 46: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:54:04,535 | server.py:218 | fit_round 47: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:54:16,924 | server.py:232 | fit_round 47 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:54:16,945 | server.py:166 | evaluate_round 47: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:54:16,946 | server.py:218 | fit_round 48: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:54:28,982 | server.py:232 | fit_round 48 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:54:29,003 | server.py:166 | evaluate_round 48: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:54:29,005 | server.py:218 | fit_round 49: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:54:41,234 | server.py:232 | fit_round 49 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:54:41,258 | server.py:166 | evaluate_round 49: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:54:41,260 | server.py:218 | fit_round 50: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:54:53,542 | server.py:232 | fit_round 50 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:54:53,566 | server.py:166 | evaluate_round 50: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:54:53,568 | server.py:218 | fit_round 51: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:55:05,650 | server.py:232 | fit_round 51 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:55:05,674 | server.py:166 | evaluate_round 51: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:55:05,675 | server.py:218 | fit_round 52: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:55:18,297 | server.py:232 | fit_round 52 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:55:18,316 | server.py:166 | evaluate_round 52: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:55:18,318 | server.py:218 | fit_round 53: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:55:30,710 | server.py:232 | fit_round 53 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:55:30,737 | server.py:166 | evaluate_round 53: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:55:30,738 | server.py:218 | fit_round 54: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:55:42,718 | server.py:232 | fit_round 54 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:55:42,745 | server.py:166 | evaluate_round 54: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:55:42,746 | server.py:218 | fit_round 55: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:55:55,624 | server.py:232 | fit_round 55 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:55:55,642 | server.py:166 | evaluate_round 55: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:55:55,643 | server.py:218 | fit_round 56: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:56:08,838 | server.py:232 | fit_round 56 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:56:08,861 | server.py:166 | evaluate_round 56: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:56:08,862 | server.py:218 | fit_round 57: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:56:20,998 | server.py:232 | fit_round 57 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:56:21,020 | server.py:166 | evaluate_round 57: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:56:21,021 | server.py:218 | fit_round 58: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:56:33,018 | server.py:232 | fit_round 58 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:56:33,042 | server.py:166 | evaluate_round 58: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:56:33,043 | server.py:218 | fit_round 59: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:56:45,522 | server.py:232 | fit_round 59 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:56:45,544 | server.py:166 | evaluate_round 59: no clients selected, cancel
# DEBUG flwr 2023-07-12 21:56:45,545 | server.py:218 | fit_round 60: strategy sampled 10 clients (out of 10)
# DEBUG flwr 2023-07-12 21:56:58,760 | server.py:232 | fit_round 60 received 10 results and 0 failures
# INFO flwr 2023-07-12 21:56:58,781 | server.py:166 | evaluate_round 60: no clients selected, cancel
# INFO flwr 2023-07-12 21:56:58,783 | server.py:147 | FL finished in 734.3600657843053
# INFO flwr 2023-07-12 21:56:58,784 | app.py:218 | app_fit: losses_distributed []
# INFO flwr 2023-07-12 21:56:58,785 | app.py:219 | app_fit: metrics_distributed_fit {}
# INFO flwr 2023-07-12 21:56:58,786 | app.py:220 | app_fit: metrics_distributed {}
# INFO flwr 2023-07-12 21:56:58,787 | app.py:221 | app_fit: losses_centralized []
# INFO flwr 2023-07-12 21:56:58,788 | app.py:222 | app_fit: metrics_centralized {}
